# %% [markdown]
# # Trace Upstream Script
# ## Version 2: Directly create upstream trib feature classes
# Kernel: Python 2
#
# Developed by: Curtis Fang

# %%
import arcpy
import numpy as np
import pandas as pd

# %% [markdown]
# ### Set GDB directory

# %%
# arcpy.env.workspace='P:\GIS\Projects\LARiver_Watershed_Projects\General\Shapefiles\Subwatersheds\SubWSTributary.gdb'
arcpy.env.workspace='C:\Users\cfang\Documents\GitHub\TraceUpstream\sandbox.gdb'
input_data='LAC_catchment'

# %% [markdown]
# ### Import input feature class as a pandas dataframe

# %%
arcpy.conversion.TableToExcel(Input_Table=input_data,
                              Output_Excel_File='Output/input.xls'
                             )
df = pd.read_excel('output/input.xls')

# %%
orig_cols=df.columns
orig_cols
# Out:
# Index([u'OBJECTID_1', u'OBJECTID', u'NAME', u'NAME2', u'WATERSHED', u'AREA_AC',
#        u'NEWMC', u'IMPCOVMC', u'ICONFIGMC', u'ROADDMC', u'SLOPEMC',
#        u'COMBINEDMC', u'MC_ID', u'WATERSHE_1', u'NEW_WSID', u'NEW_DS_ID',
#        u'RECCOMEN_1', u'PREC_97_06', u'PREC_GAGE', u'PRE_97_06', u'PEVT_87_06',
#        u'DUMMY', u'IRRIGATION', u'OLD_MC', u'NEW_MC', u'FINAL_MC', u'SAME_MC',
#        u'IMP_COVER', u'IMP_CONFIG', u'ROAD_DENS', u'SLOPE_MC', u'SURO_INAC',
#        u'PERO_INAC', u'RCH_GRP', u'Shape_Leng', u'Shape_Le_1', u'DEPTH_RATI',
#        u'Shape_Length', u'Shape_Area', u'CatID', u'DwnCatID'],
#       dtype='object')

# %% [markdown]
# ### Set target downstream catchment and catchment ID columns

# %%
#Input
target_ID='c6475'
id_col='CatID'
ds_col='DwnCatID'

# %% [markdown]
# ### Define output variables

# %%
temp_input="_temp_input_"+target_ID
temp_input_xls='Output/'+temp_input+'.xls'
table_gdb='a'+target_ID+'_upstream'
table_csv=filename = 'Output/'+table_gdb+'.csv'
fc_output='upstream_'+target_ID

# %% [markdown]
# ### Trace upstream

# %%
_neighbors = df[df[ds_col] == target_ID]
upstream = _neighbors
while not _neighbors.empty:
    _neighbors = df[df[ds_col].isin(_neighbors[id_col])]
    upstream = upstream.append(_neighbors, ignore_index=True)
#Comment out the line below if one does not want to include the catchment itself
upstream=upstream.append(df[df[id_col]==target_ID],ignore_index=True)

# %%
exc_cols=orig_cols.difference([id_col])
upstream = upstream.drop(exc_cols,1)
upstream
# Out:
#      CatID
# 0    c6476
# 1    c6477
# 2    c6478
# 3    c6482
# 4    c6479
# 5    c6480
# 6    c6483
# 7    c6491
# 8    c6481
# 9    c6484
# 10   c6492
# 11   c6493
# 12   c6494
# 13   c6485
# 14   c6496
# 15   c6495
# 16   c6488
# 17   c6486
# 18   c6497
# 19   c6498
# 20   c6489
# 21   c6490
# 22   c6487
# 23   c6499
# 24   c6501
# 25   c6500
# 26   c6502
# 27   c6503
# 28   c6504
# 29   c6506
# ..     ...
# 507  c6983
# 508  c6985
# 509  c6982
# 510  c6972
# 511  c6965
# 512  c6966
# 513  c6973
# 514  c7005
# 515  c6999
# 516  c6987
# 517  c6986
# 518  c6984
# 519  c7008
# 520  c7006
# 521  c7001
# 522  c7000
# 523  c6988
# 524  c6990
# 525  c7007
# 526  c7009
# 527  c7003
# 528  c7002
# 529  c6991
# 530  c6989
# 531  c6992
# 532  c6993
# 533  c7004
# 534  c7010
# 535  c7011
# 536  c6475
#
# [537 rows x 1 columns]

# %%
upstream.to_csv(table_csv,index=False)
arcpy.conversion.TableToTable(table_csv,
                             arcpy.env.workspace,
                            table_gdb)
# Out:
# <Result 'C:\\Users\\cfang\\Documents\\GitHub\\TraceUpstream\\sandbox.gdb\\ac6475_upstream'>

# %%
#Create a temp duplicate shapefile in prep for join field - avoid modifying the original input
arcpy.conversion.FeatureClassToFeatureClass(input_data, 
                                            arcpy.env.workspace, 
                                            temp_input)
# Out:
# <Result 'C:\\Users\\cfang\\Documents\\GitHub\\TraceUpstream\\sandbox.gdb\\_temp_input_c6475'>

# %%
arcpy.management.JoinField(in_data=temp_input,
                          in_field=id_col,
                          join_table= table_gdb,
                          join_field=id_col)
# Out:
# <Result 'C:\\Users\\cfang\\Documents\\GitHub\\TraceUpstream\\sandbox.gdb\\_temp_input_c6475'>

# %%
# Check join result
arcpy.conversion.TableToExcel(Input_Table=temp_input,Output_Excel_File=temp_input_xls)
df3 = pd.read_excel(temp_input_xls)
df3
# Out:
#       OBJECTID_1  OBJECTID      NAME     NAME2 WATERSHED      AREA_AC  NEWMC  \
# 0              1         1    BI57-8    BI57-9   ballona  1479.189941   1101
# 1              2         2    BI57-7    BI57-8   ballona  1535.420044   1101
# 2              3         3    STONE1    STONE3   ballona  1489.010010   1001
# 3              4         4    BNDCT1    BNDCT2   ballona  1749.709961   1001
# 4              5         5    SEPUL1    SEPUL2   ballona  2210.479980   1001
# 5              6         6    MNDVL1    SNMON1   ballona  2336.600098      1
# 6              7         7   BI497-1   BI497-2   ballona  1004.309998   1001
# 7              8         8    MORGA1    SEPUL2   ballona   938.966980   1001
# 8              9         9    RUSTC1    RUSTC2   ballona  1482.829956      1
# 9             10        10    BI57-1    BI57-5   ballona  1184.619995   1100
# 10            11        11    SLLVN1    SNMON1   ballona  1823.079956      1
# 11            12        12    FRANK1    COLDW1   ballona   776.513977   1001
# 12            13        13    PANPC1   DDI11-4   ballona  4751.859863   1101
# 13            14        14    BI57-4    BI57-5   ballona  1917.449951   1100
# 14            15        15     BI496    COLDW2   ballona   474.623993   1001
# 15            16        16    COLDW1    COLDW2   ballona   717.656006   1001
# 16            17        17    BI5237     BI498   ballona   406.859985   1001
# 17            18        18    BI57-2    BI57-5   ballona  1079.569946   1100
# 18            19        19     BI411    BNDCT2   ballona   407.022003   1001
# 19            20        20  BI1102-1  BI1102-2   ballona  1310.369995   1101
# 20            21        21    SYNEZ1    SYNEZ2   ballona  1297.280029      1
# 21            22        22   DDI11-1   DDI11-3   ballona  2259.550049   1001
# 22            23        23    RUSTC2    RUSTC3   ballona  2146.199951      1
# 23            24        24    TEMES1     Ocean   ballona  1569.750000   1001
# 24            25        25    BUNDY1    BUNDY3   ballona   499.875000   1001
# 25            26        26    BI5238     BI498   ballona   241.259003   1001
# 26            27        27   DDI11-3   DDI11-4   ballona   855.408020   1101
# 27            28        28    QUARY1    SYNEZ2   ballona   524.322021      1
# 28            29        29    BI57-3    BI57-4   ballona   504.265991   1110
# 29            30        30    KENTR1    KENTR2   ballona   973.705994   1001
# ...          ...       ...       ...       ...       ...          ...    ...
# 2675        2676      9021     DUMMY     STORE   lariver     1.000000      1
# 2676        2677      9022     DUMMY     STORE   lariver     1.000000      1
# 2677        2678      9023     DUMMY     STORE   lariver     1.000000      1
# 2678        2679      9024     DUMMY     STORE   lariver     1.000000      1
# 2679        2680      9025     DUMMY     STORE   lariver     1.000000      1
# 2680        2681      9026     DUMMY     STORE   lariver     1.000000      1
# 2681        2682      9027     DUMMY     STORE   lariver     1.000000      1
# 2682        2683      9028     DUMMY     STORE   lariver     1.000000      1
# 2683        2684      9029     DUMMY     STORE   lariver     1.000000      1
# 2684        2685      9030     DUMMY     STORE   lariver     1.000000      1
# 2685        2686      9031     DUMMY     STORE   lariver     1.000000      1
# 2686        2687      9032     DUMMY     STORE   lariver     1.000000      1
# 2687        2688      9033     DUMMY     STORE   lariver     1.000000      1
# 2688        2689      9034     DUMMY     STORE   lariver     1.000000      1
# 2689        2690      9035     DUMMY     STORE   lariver     1.000000      1
# 2690        2691      9036     DUMMY     STORE   lariver     1.000000      1
# 2691        2692      9037     DUMMY     STORE   lariver     1.000000      1
# 2692        2693      9038     DUMMY     STORE   lariver     1.000000      1
# 2693        2694      9039     DUMMY     STORE   lariver     1.000000      1
# 2694        2695      9040     DUMMY     STORE   lariver     1.000000      1
# 2695        2696      9041     DUMMY     STORE   lariver     1.000000      1
# 2696        2697      9042     DUMMY     STORE   lariver     1.000000      1
# 2697        2698      9043     DUMMY     STORE   lariver     1.000000      1
# 2698        2699      9044     DUMMY     STORE   lariver     1.000000      1
# 2699        2700      9045     DUMMY     STORE   lariver     1.000000      1
# 2700        2701      9046     DUMMY     STORE   lariver     1.000000      1
# 2701        2702      9047     DUMMY     STORE   lariver     1.000000      1
# 2702        2703      9048     DUMMY     STORE   lariver     1.000000      1
# 2703        2704      9049     DUMMY     STORE   lariver     1.000000      1
# 2704        2705      9050     DUMMY     STORE   lariver     1.000000      1
#
#       IMPCOVMC  ICONFIGMC  ROADDMC   ...     PERO_INAC RCH_GRP    Shape_Leng  \
# 2681      1.000000           0  c9027       c0  11954.780220  8.926482e+06
# 2682      1.000000           0  c9028       c0  11850.710526  8.766997e+06
# 2683      1.000000           0  c9029       c0  12316.442218  9.480722e+06
# 2684      1.000000           0  c9030       c0  12406.518241  9.618761e+06
# 2685      1.000000           0  c9031       c0  12023.797524  8.969323e+06
# 2686      1.000000           0  c9032       c0  11310.661443  7.988080e+06
# 2687      1.000000           0  c9033       c0  11196.522359  7.831466e+06
# 2688      1.000000           0  c9034       c0  11659.747397  8.465128e+06
# 2689      1.000000           0  c9035       c0  11746.830096  8.583877e+06
# 2690      1.000000           0  c9036       c0  11997.019120  8.932027e+06
# 2691      1.000000           0  c9037       c0  11375.560035  8.079919e+06
# 2692      1.000000           0  c9038       c0  11236.017415  7.887927e+06
# 2693      1.000000           0  c9039       c0  11707.769668  8.539395e+06
# 2694      1.000000           0  c9040       c0  11801.153070  8.669787e+06
# 2695      1.000000           0  c9041       c0  11786.522537  8.597921e+06
# 2696      1.000000           0  c9042       c0  11181.493737  7.792434e+06
# 2697      1.000000           0  c9043       c0  11017.958128  7.576100e+06
# 2698      1.000000           0  c9044       c0  11486.313529  8.196904e+06
# 2699      1.000000           0  c9045       c0  11569.654496  8.306831e+06
# 2700      1.000000           0  c9046       c0  12003.619143  8.952337e+06
# 2701      1.000000           0  c9047       c0  11435.893718  8.165741e+06
# 2702      1.000000           0  c9048       c0  11255.599958  7.915917e+06
# 2703      1.000000           0  c9049       c0  11718.259597  8.555617e+06
# 2704      1.000000           0  c9050       c0  11799.902572  8.667834e+06
#
#       CatID_1
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# ...       ...
# 2675      NaN
# 2676      NaN
# 2677      NaN
# 2678      NaN
# 2679      NaN
# 2680      NaN
# 2681      NaN
# 2682      NaN
# 2683      NaN
# 2684      NaN
# 2685      NaN
# 2686      NaN
# 2687      NaN
# 2688      NaN
# 2689      NaN
# 2690      NaN
# 2691      NaN
# 2692      NaN
# 2693      NaN
# 2694      NaN
# 2695      NaN
# 2696      NaN
# 2697      NaN
# 2698      NaN
# 2699      NaN
# 2700      NaN
# 2701      NaN
# 2702      NaN
# 2703      NaN
# 2704      NaN
#
# [2705 rows x 42 columns]

# %%
expression = id_col+'_1 IS NOT NULL' #Furture improvement: Avoid hard coding the epxression
arcpy.conversion.FeatureClassToFeatureClass(temp_input, 
                                            arcpy.env.workspace, 
                                            fc_output,
                                           expression)
# Out:
# <Result 'C:\\Users\\cfang\\Documents\\GitHub\\TraceUpstream\\sandbox.gdb\\upstream_c6475'>

# %%
#if run into already exist error, run this block
#arcpy.management.Delete(fc_output)
# arcpy.env.overwriteOutput = True

# %% [markdown]
# ### Clean up temp files

# %%
arcpy.management.Delete(temp_input)
arcpy.management.DeleteField(fc_output,id_col+'_1')
# Out:
# <Result 'C:\\Users\\cfang\\Documents\\GitHub\\TraceUpstream\\sandbox.gdb\\upstream_c6475'>
